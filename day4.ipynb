# %%
n = int(input("enter the no"))
if n%2:
    print("the number is odd")
else:
    print("the number is even")
# Out:
# enter the no 5
# the number is odd

# %%
n = int(input("enter the no"))
if n>0:
    print("+ive")
elif n<0:
    print("-ive")
else:
    print("the no is 0")
# Out:
# enter the no 0
# 0

# %%
n = int(input("enter the no"))
if n<=10:
    print("child")
elif n<19:
    print("teenager")
elif n<35:
    print("adult")
elif n<101:
    print("older")
else:
    print("dead")
# Out:
# enter the no 18
# teenager

# %%
n = int(input("enter the no"))
if n<60:
    print("F")
elif n<70:
    print("D")
elif n<80:
    print("c")
elif n<90:
    print("B")
elif n<101:
    print("A")
else:
    print("100 ke andar likh")
# Out:
# enter the no 123
# 100 ke andar likh

# %%
n = (input("enter the alphabet"))
if n in "aeiouAEIOU":
    print("vowel")
else :
    print("consonent")
# Out:
# enter the no asdfghj
# consonent

# %%
d = {}
while True:
    ch = int(input("""enter 0 if u want to create account 
enter 1 if u have already an account 
:"""))
    if ch:
        user=input("enter user name:")
        passwd = input("enter password:")
        if user in d and d[user] == passwd:
            print("login successfully")
            break 
        else:
            print("esa koi account hi nahi h")
    else:
        user=input("enter user name:")
        passwd = input("enter password:")
        d[user]=passwd
        print("registration successfully")
# Out:
# enter 0 if u want to create account
# enter 1 if u have already an account
# : 0
# enter user name: n
# enter password: n
# registration successfully
# enter 0 if u want to create account
# enter 1 if u have already an account
# : 1
# enter user name: n
# enter password: n
# login successfully

# %%
l=[]
for _ in range(3):
    n = int(input("enter the number:"))
    l.append(n)
l.sort()
print(l[-1])
# Out:
# enter the number: 8
# enter the number: 5
# enter the number: 4
# 8

# %%
n = input("enter the no of month:")
if n in ['1','3','5','7','8','10','12']:
    print("31")
elif n == '2':
    print("28")
else:
    print("30")
# Out:
# enter the no of month: 30
# 30

# %%
n = int(input(""))
if n%15 == 0:
    print("divided by 15")
elif n%5 == 0:
    print("divided by 5")
elif n%3==0:
    print("divided by 3")
else:
    print("ye 3 and 5 dono se hi divide hi nahi hota")
# Out:
#  45
# divided by 15
